# %% [markdown]
# BÀI THỰC HÀNH 1 - 22521658 - PHAN THỊ TƯỜNG VI - NHÓM 15

# %%
# !pip install scipy
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: C:\Users\15520\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd 
from scipy import stats

# %%
data = pd.read_csv('BT1.225092302_energy_drink_survey.csv', delimiter=";") 
data.head()
# Out:
#    Respondent  Gender Brand Preference
# 0           1    Male          Brand 3
# 1           2  Female          Brand 3
# 2           3    Male          Brand 3
# 3           4    Male          Brand 1
# 4           5    Male          Brand 1

# %% [markdown]
# Tạo bảng chéo và in ra kết quả thống kê theo 2 thuộc tính Gender, Brand Preference. Sử dụng crosstab

# %%
print(data.columns)
# Out:
# Index(['Respondent', 'Gender', 'Brand Preference'], dtype='object')

# %%
crosstab_result = pd.crosstab(data['Gender'], data['Brand Preference'], margins=True)
print(crosstab_result)
# Out:
# Brand Preference  Brand 1  Brand 2  Brand 3  All
# Gender
# Female                  9        6       22   37
# Male                   25       17       21   63
# All                    34       23       43  100

# %% [markdown]
# Kiểm định Chi-square. Sử dụng chi2_contigenvy()

# %% [markdown]
# Giả thuyết cần kiểm tra:
# H0: Không có mối quan hệ giữa Gender và Brand Preference, tức là việc một người chọn thương hiệu nào là hoàn toàn ngẫu nhiên, không phụ thuộc vào giới tính.
# H1: Có mối quan hệ giữa Gender và Brand Preference, nghĩa là giới tính có ảnh hưởng đến sở thích thương hiệu.

# %%
from scipy.stats import chi2_contingency

# %%
from scipy.stats import chi2

alpha = 0.05 
df = 6 

chi_critical = chi2.ppf(1 - alpha, df)

print(f"Giá trị tới hạn của X^2(0.05,6): {chi_critical:.4f}")
# Out:
# Giá trị tới hạn của X^2(0.05,6): 12.5916

# %%
chi2, p, dof, expected = chi2_contingency(crosstab_result)

print(f"Chi-square: {chi2}")
print(f"P-value: {p}")
print(f"Degrees of Freedom: {dof}")
print("Expected Frequencies Table:")
print(pd.DataFrame(expected, index=crosstab_result.index, columns=crosstab_result.columns))
# Out:
# Chi-square: 6.4924250792329055
# P-value: 0.37034281528737867
# Degrees of Freedom: 6
# Expected Frequencies Table:
# Brand Preference  Brand 1  Brand 2  Brand 3    All
# Gender
# Female              12.58     8.51    15.91   37.0
# Male                21.42    14.49    27.09   63.0
# All                 34.00    23.00    43.00  100.0

# %% [markdown]
# Kết luận: X2(Chi-square) < X2(alpha,df) => Chấp nhận H0. Giới tính không ảnh hưởng đên thương hiệu, một người chọn thương hiệu nào là hoàn toàn ngẫu nhiên, không phụ thuộc vào giới tính.

# %%
# !jupyter nbconvert --to html BTTH1_CHISQUARE.ipynb
# Out:
# [NbConvertApp] Converting notebook BTTH1_CHISQUARE.ipynb to html
# [NbConvertApp] Writing 284999 bytes to BTTH1_CHISQUARE.html
