# %%
import pandas as pd

# %%
folder_path = r"D:\PTDLKinhDoanh\Dataset\all_fuels_data.csv"  
df1 = pd.read_csv(folder_path)  # Không có dấu nháy đơn

print(df1.head())  # Xem 5 dòng đầu tiên
# Out:
#   ticker  commodity        date       open       high        low      close  \
# 0   CL=F  Crude Oil  2000-08-23  31.950001  32.799999  31.950001  32.049999
# 1   CL=F  Crude Oil  2000-08-24  31.900000  32.240002  31.400000  31.629999
# 2   CL=F  Crude Oil  2000-08-25  31.700001  32.099998  31.320000  32.049999
# 3   CL=F  Crude Oil  2000-08-28  32.040001  32.919998  31.860001  32.869999
# 4   CL=F  Crude Oil  2000-08-29  32.820000  33.029999  32.560001  32.720001
#
#    volume
# 0   79385
# 1   72978
# 2   44601
# 3   46770
# 4   49131

# %%
print(df1.isnull().sum())
# Out:
# ticker       0
# commodity    0
# date         0
# open         0
# high         0
# low          0
# close        0
# volume       0
# dtype: int64

# %%
folder_path = r"D:\PTDLKinhDoanh\Dataset\Brent_Crude_Oil_data.csv"
df2 = pd.read_csv(folder_path)  # Không có dấu nháy đơn

print(df2.head())  # Xem 5 dòng đầu tiên
# Out:
#          date       open       high        low      close  volume
# 0  2007-07-30  75.849998  76.529999  75.440002  75.739998    2575
# 1  2007-07-31  75.699997  77.169998  75.669998  77.050003    3513
# 2  2007-08-01  77.000000  77.059998  74.860001  75.349998    3930
# 3  2007-08-02  75.220001  76.209999  74.269997  75.760002    6180
# 4  2007-08-03  75.389999  76.000000  74.529999  74.750000    4387

# %%
print(df2.isnull().sum())
# Out:
# date      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64

# %%
folder_path = r"D:\PTDLKinhDoanh\Dataset\Crude_Oil_data.csv"
df3 = pd.read_csv(folder_path)  # Không có dấu nháy đơn

print(df3.head())  # Xem 5 dòng đầu tiên
# Out:
#          date       open       high        low      close  volume
# 0  2000-08-23  31.950001  32.799999  31.950001  32.049999   79385
# 1  2000-08-24  31.900000  32.240002  31.400000  31.629999   72978
# 2  2000-08-25  31.700001  32.099998  31.320000  32.049999   44601
# 3  2000-08-28  32.040001  32.919998  31.860001  32.869999   46770
# 4  2000-08-29  32.820000  33.029999  32.560001  32.720001   49131

# %%
print(df3.isnull().sum())
# Out:
# date      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64

# %%
folder_path = r"D:\PTDLKinhDoanh\Dataset\Heating_Oil_data.csv"
df4 = pd.read_csv(folder_path)  # Không có dấu nháy đơn

print(df4.head())  # Xem 5 dòng đầu tiên
print(df4.isnull().sum())
# Out:
#          date   open   high     low   close  volume
# 0  2000-09-01  0.985  0.991  0.9705  0.9764   14679
# 1  2000-09-05  0.995  0.998  0.9750  0.9797   17365
# 2  2000-09-06  0.985  1.000  0.9810  0.9966   18879
# 3  2000-09-07  0.990  1.030  0.9880  1.0295   23851
# 4  2000-09-08  1.012  1.020  0.9910  0.9949   23189
# date      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64

# %%
folder_path = r"D:\PTDLKinhDoanh\Dataset\Natural_Gas_data.csv"
df5 = pd.read_csv(folder_path)  # Không có dấu nháy đơn

print(df5.head())  # Xem 5 dòng đầu tiên
print(df5.isnull().sum())
# Out:
#          date  open   high   low  close  volume
# 0  2000-08-30  4.65  4.815  4.63  4.805   34954
# 1  2000-08-31  4.82  4.870  4.74  4.780   25787
# 2  2000-09-01  4.75  4.860  4.75  4.835     113
# 3  2000-09-05  4.85  4.975  4.84  4.960   26096
# 4  2000-09-06  4.99  5.110  4.96  5.065   32764
# date      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64

# %%
folder_path = r"D:\PTDLKinhDoanh\Dataset\RBOB_Gasoline_data.csv"
df6 = pd.read_csv(folder_path)  # Không có dấu nháy đơn

print(df6.head())  # Xem 5 dòng đầu tiên
print(df6.isnull().sum())
# Out:
#          date    open    high    low   close  volume
# 0  2000-11-01  0.8890  0.8970  0.882  0.8840   16223
# 1  2000-11-02  0.8750  0.8876  0.863  0.8688   17216
# 2  2000-11-03  0.8675  0.8750  0.860  0.8695   10170
# 3  2000-11-06  0.8600  0.8850  0.856  0.8825   16184
# 4  2000-11-07  0.8930  0.9000  0.886  0.8910   15717
# date      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64
